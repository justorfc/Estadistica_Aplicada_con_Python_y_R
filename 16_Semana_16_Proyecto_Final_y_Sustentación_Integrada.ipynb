# %% [markdown]
# <a href="https://colab.research.google.com/github/justorfc/Estadistica_Aplicada_con_Python_y_R_2026_2/blob/main/16_Semana_16_Proyecto_Final_y_Sustentaci%C3%B3n_Integrada.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Este es el último Notebook de la propuesta estructurada para la **Semana 16**, la culminación del curso. En esta semana final no se introducen temas nuevos; el esfuerzo se centra completamente en la integración de saberes, la validación de la reproducibilidad científica y la sustentación oral del **Proyecto Integrador**.
#
# # Semana 16: Proyecto Final y Sustentación Integrada
#
# **Resultado de aprendizaje:** Integra y sustenta un análisis estadístico aplicado, reproducible y éticamente documentado, defendiendo las decisiones metodológicas y el uso de inteligencia artificial.
#
# ---
#
# #### Sesión 1: Auditoría de Reproducibilidad y Cierre de Repositorios (80 - 90 minutos)
#
# **Objetivo:** Garantizar que los flujos de trabajo en Python y R funcionen de principio a fin sin errores locales, consolidar la documentación y preparar el despliegue en GitHub.
#
# * **20 min - Revisión de "Ciencia Reproducible" (Lápiz, Pantalla y GitHub):**
# * *Actividad:* Discusión sobre el principio de reproducibilidad: "Si tu código solo corre en tu computadora, no es ciencia".
# * Explicación de los últimos comandos de Git (`add`, `commit`, `push`) para asegurar que los repositorios estén actualizados con el cuaderno de Google Colab, el archivo `.qmd` / `.Rmd`, y la base de datos agrícola elegida.
#
#
# * **45 min - Trabajo de Auditoría Técnica y Depuración:**
# * Los estudiantes ejecutan un "Run All" (Ejecutar todo) en Google Colab y un "Render" final en Posit Cloud.
# * El docente actúa como consultor de alto nivel, resolviendo dependencias de paquetes rotas o errores de rutas de archivos.
#
#
# * **25 min - Revisión de la Bitácora de IA y Ética:**
# * Verificación de que el documento incluya los *prompts* clave utilizados a lo largo del semestre y las reflexiones críticas sobre cómo el estudiante tuvo que corregir a la máquina (Control Humano).
#
#
#
# ---
#
# #### Sesión 2: Defensa Oral y Sustentación (80 - 90 minutos)
#
# **Objetivo:** Evaluar la apropiación del conocimiento, la capacidad de interpretación ingenieril de los resultados y la suficiencia en el manejo de la estadística sin dependencia de los agentes de IA.
#
# * **10 min - Encuadre de la Evaluación:**
# * Repaso rápido de la rúbrica: Calidad de datos, ajuste de distribuciones, diagnóstico del modelo de regresión, evaluación de series de tiempo y claridad en la comunicación.
#
#
# * **70 min - Sustentaciones Individuales (Formato Ejecutivo):**
# * Cada estudiante cuenta con 5 a 7 minutos para proyectar su informe renderizado y presentar sus hallazgos más críticos al "comité evaluador" (el resto de la clase y el docente).
# * *Ronda de preguntas socráticas:* El docente realiza preguntas específicas sobre los supuestos matemáticos, la justificación de la distribución elegida o la interpretación de un coeficiente. **El estudiante no puede consultar al chatbot durante esta fase.**
#
#
# * **10 min - Cierre de la Asignatura:**
# * Reflexión final sobre el modelo "El lápiz y el algoritmo" y cómo la estadística potenciará su futura práctica en la ingeniería.
#
#
#
# ---
#
# A continuación, el contenido listo para el último cuaderno de Google Colab. Este cuaderno funcionará como la **Lista de Chequeo Maestra** del proyecto integrador.
#
# ---
#
# ### Celda de Texto 1
#
# ```markdown
# # Semana 16: Proyecto Final Integrador
# **Asignatura:** Estadística Aplicada con Python y R
# **Programa:** Ingeniería Agrícola - Universidad de Sucre
# **Profesor:** Justo Rafael Fuentes Cuello
#
# ---
#
# ### Misión Final: De Datos a Evidencia
# Durante 15 semanas hemos construido un arsenal analítico. Hemos pasado desde la limpieza de datos hasta el pronóstico del futuro con algoritmos de Machine Learning y Series de Tiempo.
#
# Hoy, la Inteligencia Artificial da un paso atrás y **el ingeniero agrícola da un paso al frente**. Este cuaderno no contiene código nuevo. Es tu rúbrica de verificación. Debes asegurarte de que tu proyecto final aborde un problema real de la ingeniería agrícola, integrando los cuatro grandes ejes del semestre de manera lógica, reproducible y éticamente documentada.
#
# ```
#
# ### Celda de Código 1

# %%
# Bloque de validación de entorno
# Asegúrate de importar todas las librerías que tu proyecto necesita para correr de un solo golpe.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
import statsmodels.api as sm
from sklearn.model_selection import train_test_split

print("Entorno validado. Ejecuta el resto de tu análisis secuencialmente.")

# %% [markdown]
# ### ✅ Eje I y II: Calidad de Datos y EDA (Análisis Exploratorio)
# Revisa tu informe y marca mentalmente esta lista:
# - [ ] **Contexto:** ¿Explicaste claramente el origen de tus datos (clima, suelo, maquinaria, riego)?
# - [ ] **Limpieza:** ¿Manejaste los valores nulos (NaN) y detectaste valores atípicos absurdos justificando tu decisión de conservarlos o filtrarlos?
# - [ ] **Estadística Descriptiva:** ¿Calculaste medidas de tendencia, dispersión, sesgo y curtosis para tus variables principales?
# - [ ] **Visualización Cruzada:** ¿Incluiste matrices de correlación o gráficos de facetas que muestren la relación entre tus variables?

# %% [markdown]
# ### ✅ Eje III: Distribuciones de Probabilidad Extremas
# Si tu problema involucra diseño hidrológico o análisis de riesgos (precipitaciones máximas, caudales, rendimientos mínimos):
# - [ ] **Ajuste Matemático:** ¿Ajustaste al menos dos distribuciones teóricas diferentes (ej. Normal vs. Gamma/Lognormal)?
# - [ ] **Diagnóstico:** ¿Presentaste los gráficos Q-Q para validar el ajuste de las colas?
# - [ ] **Selección:** ¿Utilizaste el AIC o la prueba de Kolmogorov-Smirnov para justificar objetivamente tu modelo ganador?
# - [ ] **Ingeniería:** ¿Calculaste un cuantil crítico (ej. Periodo de Retorno) con base en la distribución ganadora?

# %% [markdown]
# ### ✅ Eje IV: Regresión, Modelación y Validación
# Si buscas predecir un resultado (ej. Rendimiento) a partir de múltiples factores:
# - [ ] **Especificación:** ¿Construiste un modelo de regresión (múltiple o no lineal) y justificaste la inclusión de las variables?
# - [ ] **Diagnóstico de Supuestos:** ¿Presentaste los gráficos de residuos para demostrar normalidad y homocedasticidad?
# - [ ] **Métricas Reales:** ¿Particionaste tus datos (Train/Test) y calculaste el MAE o RMSE sobre el conjunto ciego de prueba para evitar el sobreajuste?
# - [ ] **Interpretación:** ¿Explicaste qué significan físicamente los coeficientes matemáticos hallados?

# %% [markdown]
# ### ✅ Eje V: Memoria y Pronóstico (Series de Tiempo)
# Si tus datos tienen un orden temporal estricto (evolución mensual/anual):
# - [ ] **Índice Temporal:** ¿Configuraste correctamente las fechas como índice de tu DataFrame/Objeto temporal?
# - [ ] **Descomposición:** ¿Aislaste matemáticamente la Tendencia y la Estacionalidad, interpretando su significado?
# - [ ] **Inercia:** ¿Mostraste gráficos ACF/PACF para analizar la memoria del sistema?
# - [ ] **Pronóstico:** ¿Generaste una proyección futura (ej. modelo SARIMA o auto.arima) incluyendo su intervalo de confianza (bandas de sombra)?

# %% [markdown]
# ### 🛑 Reserva Cognitiva, Bitácora de IA y Sustentación
#
# El software calculó los números, pero tú tomaste las decisiones. Antes de presentar, verifica:
# 1. **La Bitácora de IA:** Tu proyecto debe incluir un apartado donde documentes los *prompts* más importantes que utilizaste con ChatGPT, Claude o Gemini, detallando qué alucinaciones o errores sintácticos cometió la máquina y cómo aplicaste tu criterio humano para corregirlos.
# 2. **Preparación Socrática:** Repasa tus apuntes manuscritos del semestre. Durante la sustentación oral, se te preguntará por el razonamiento detrás de los códigos. No puedes depender del agente para responder por qué elegiste el RMSE en lugar del R-cuadrado para validar tu regresión.

# %% [markdown]
# ### Instrucciones Finales para R y Posit Cloud (Entrega Definitiva)
#
# **Misión:** Consolidar el documento reproducible final en **Quarto (.qmd) o RMarkdown** utilizando Posit Cloud y alojarlo en tu portafolio público.
#
# **Pasos a seguir:**
# 1. Abre tu proyecto integrador en Posit Cloud.
# 2. Verifica que el botón **Knit** (o Render en Quarto) compile un documento HTML o PDF impecable, sin errores de ejecución a mitad de camino. Oculta las advertencias innecesarias de las librerías utilizando `warning=FALSE` y `message=FALSE` en tus *chunks*.
# 3. Asegúrate de que los gráficos de `ggplot2` tengan títulos formales, unidades en los ejes y leyendas claras.
# 4. **Git y GitHub:** Realiza tu último `commit` con el mensaje *"Entrega final de Proyecto Integrador de Estadística Agrícola"* y haz `push` a tu repositorio remoto.
# 5. **Éxito:** Entrega el enlace de tu repositorio y prepárate para brillar en tu sustentación.
