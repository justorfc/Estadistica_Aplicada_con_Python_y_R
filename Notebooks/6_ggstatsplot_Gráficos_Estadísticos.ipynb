# %% [markdown]
# # **[ggstatsplot](https://indrajeetpatil.github.io/ggstatsplot/)** Graficos con detalles estadísticos

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Razón de ser**
#
# “Lo que se debe buscar en los diseños para la visualización de información es una representación clara de la complejidad. No la complicación de lo simple; más bien… la revelación del complejo”. -Edward R. Tufte
#
# {[ggstatsplot](https://indrajeetpatil.github.io/ggstatsplot/)}es una extensión del {[ggplot2](https://github.com/tidyverse/ggplot2)}paquete para crear gráficos con detalles de pruebas estadísticas incluidos en los propios gráficos ricos en información. En un flujo de trabajo típico de análisis de datos exploratorios, la visualización de datos y el modelado estadístico son dos fases diferentes: la visualización informa al modelado y el modelado, a su vez, puede sugerir un método de visualización diferente, y así sucesivamente. La idea central de ggstatsplot es simple: combinar estas dos fases en una en forma de gráficos con detalles estadísticos, lo que hace que la exploración de datos sea más sencilla y rápida.

# %% [markdown]
# # **Instalación**
#
# ```
# install.packages("ggstatsplot")
# ```

# %%
install.packages("ggstatsplot")

# %% [markdown]
# # **Citación**
#
# Si desea citar este paquete en una revista científica o en cualquier otro contexto, ejecute el siguiente código en su Rconsola:
#
# ```
# citation("ggstatsplot")
# ```

# %%
citation("ggstatsplot")

# %% [markdown]
# # **Documentación y ejemplos**
#
# Para ver la documentación detallada de cada función en la versión estable de CRAN del paquete, consulte:
#
# 1. [Publicación](https://joss.theoj.org/papers/10.21105/joss.03167)
# 2. [Viñetas](https://indrajeetpatil.github.io/ggstatsplot/articles/)
# 3. [Presentación](https://indrajeetpatil.github.io/ggstatsplot_slides/slides/ggstatsplot_presentation.html#1)

# %% [markdown]
# # **Resumen de Gráficos disponibles**
#
# |Función|Trama|Descripción|
# |-------|-----|-----------|
# |[ggbetweenstats()](https://indrajeetpatil.github.io/ggstatsplot/reference/ggbetweenstats.html)|Gráficos de violín	para comparaciones entre grupos/condiciones|
# |[ggwithinstats()](https://indrajeetpatil.github.io/ggstatsplot/reference/ggwithinstats.html)|Gráficos de violín	para comparaciones dentro de grupos/condiciones|
# |[gghistostats()](https://indrajeetpatil.github.io/ggstatsplot/reference/gghistostats.html)|histogramas	para distribución sobre variable numérica|
# |[ggdotplotstats()](https://indrajeetpatil.github.io/ggstatsplot/reference/ggdotplotstats.html)|diagramas/gráficos de puntos	para distribución sobre variable numérica etiquetada|
# |[ggscatterstats()](https://indrajeetpatil.github.io/ggstatsplot/reference/ggscatterstats.html)|gráfico de dispersión	para la correlación entre dos variables|
# |[ggcorrmat()](https://indrajeetpatil.github.io/ggstatsplot/reference/ggcorrmat.html)|matrices de correlación	para correlaciones entre múltiples variables|
# |[ggpiestats()](https://indrajeetpatil.github.io/ggstatsplot/reference/ggpiestats.html)|gráficos circulares	para datos categóricos|
# |[ggbarstats()](https://indrajeetpatil.github.io/ggstatsplot/reference/ggbarstats.html)|gráfica de barras	para datos categóricos|
# |[ggcoefstats()](https://indrajeetpatil.github.io/ggstatsplot/reference/ggcoefstats.html)|diagramas de puntos y bigotes	para modelos de regresión y metanálisis|

# %% [markdown]
# # ANOVA simple

# %% [markdown]
# Aquí hay un ejemplo de código en R para realizar un ANOVA simple utilizando los datos del conjunto de datos `mtcars`. En este caso, asumiré que deseas realizar un ANOVA para comparar las medias de una variable numérica entre diferentes niveles de una variable categórica. Tomaré como ejemplo la variable numérica "mpg" y la variable categórica "cyl" del conjunto de datos `mtcars`:
#
# ```R
# # Carga de datos
# data(mtcars)
#
# # ANOVA simple
# modelo_anova <- aov(mpg ~ cyl, data = mtcars)
#
# # Resumen del ANOVA
# summary(modelo_anova)
# ```
#
# En este código:
#
# - Se carga el conjunto de datos `mtcars`.
# - Se utiliza la función `aov()` para ajustar un modelo ANOVA, donde "mpg" es la variable de interés y "cyl" es la variable categórica que define los grupos.
# - Se imprime un resumen del ANOVA utilizando la función `summary()`.
#
# Asegúrate de ajustar las variables según tus necesidades. Si deseas realizar un ANOVA con diferentes variables, simplemente modifica las fórmulas en la función `aov()`.
#
# Espero que esto te sea útil. Si tienes alguna pregunta adicional o necesitas más aclaraciones, no dudes en preguntar.

# %%
# Carga de datos
data(mtcars)

# ANOVA simple
modelo_anova <- aov(mpg ~ cyl, data = mtcars)

# Resumen del ANOVA
summary(modelo_anova)
# Out:
#             Df Sum Sq Mean Sq F value   Pr(>F)
# cyl          1  817.7   817.7   79.56 6.11e-10 ***
# Residuals   30  308.3    10.3
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %% [markdown]
# # ggbetweenstats()	Gráficos de violín	para comparaciones entre grupos/condiciones
#
# Para utilizar la función `ggbetweenstats()` del paquete ggstatsplot para mostrar un ANOVA simple en R, puedes hacer lo siguiente utilizando los datos de `mtcars`:
#
# ```R
# # Instala y carga los paquetes necesarios si aún no están instalados
# # install.packages(c("ggstatsplot", "ggplot2"))
# library(ggstatsplot)
# library(ggplot2)
#
# # Carga de datos
# data(mtcars)
#
# # Uso de ggbetweenstats para visualizar el ANOVA
# ggbetweenstats(
#   data = mtcars,
#   x = cyl,
#   y = mpg,
#   title = "Comparación de medias con ANOVA",
#   xlab = "Número de cilindros",
#   ylab = "Consumo de combustible (mpg)",
#   desc_stat = "mean_cl_boot", # Puedes ajustar según tus necesidades
#   test.value = 0, # Valor para comparar con la estadística descriptiva
#   test = "aov" # Especifica que deseas realizar un ANOVA
# )
# ```
#
# En este código:
#
# - Se utiliza la función `ggbetweenstats()` para visualizar la comparación de medias entre los niveles de la variable categórica (`cyl`) para la variable numérica de interés (`mpg`).
# - Los argumentos `desc_stat`, `test.value`, y `test` se configuran para mostrar la media con intervalo de confianza bootstrap, comparar con un valor de 0 y realizar un ANOVA, respectivamente.
#
# Ajusta los argumentos según tus necesidades específicas. Este código generará un gráfico de violín junto con un diagrama de puntos que muestra las comparaciones de medias entre los grupos definidos por la variable categórica.
#
# Espero que esto te sea de ayuda. Si tienes más preguntas o necesitas más aclaraciones, no dudes en preguntar.

# %%
!install.packages("ggstatsplot")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘SparseM’, ‘minqa’, ‘nloptr’, ‘numDeriv’, ‘carData’, ‘abind’, ‘quantreg’, ‘elliptic’, ‘contfrac’, ‘deSolve’, ‘plyr’, ‘lme4’, ‘pbkrtest’, ‘lmerTest’, ‘car’, ‘coda’, ‘pbapply’, ‘mvtnorm’, ‘MatrixModels’, ‘hypergeo’, ‘RcppEigen’, ‘multcompView’, ‘gmp’, ‘Rmpfr’, ‘SuppDists’, ‘kSamples’, ‘BWStest’, ‘reshape’, ‘bayestestR’, ‘reshape2’, ‘Rcpp’, ‘prismatic’, ‘afex’, ‘BayesFactor’, ‘effectsize’, ‘PMCMRplus’, ‘WRS2’, ‘zeallot’, ‘correlation’, ‘datawizard’, ‘ggcorrplot’, ‘ggplot2’, ‘ggrepel’, ‘ggside’, ‘ggsignif’, ‘insight’, ‘paletteer’, ‘parameters’, ‘patchwork’, ‘performance’, ‘statsExpressions’
#
#
# Warning message in install.packages("ggstatsplot"):
# “installation of package ‘gmp’ had non-zero exit status”
# Warning message in install.packages("ggstatsplot"):
# “installation of package ‘Rmpfr’ had non-zero exit status”
# ...

# %%
# Instala y carga los paquetes necesarios si aún no están instalados
# install.packages(c("ggstatsplot", "ggplot2"))
library(ggstatsplot)
library(ggplot2)

# Carga de datos
data(mtcars)

# Uso de ggbetweenstats para visualizar el ANOVA
ggbetweenstats(
  data = mtcars,
  x = cyl,
  y = mpg,
  title = "Comparación de medias con ANOVA",
  xlab = "Número de cilindros",
  ylab = "Consumo de combustible (mpg)",
  desc_stat = "mean_cl_boot", # Puedes ajustar según tus necesidades
  test.value = 0, # Valor para comparar con la estadística descriptiva
  test = "aov" # Especifica que deseas realizar un ANOVA
)
# Out:
# Error in library(ggstatsplot): there is no package called ‘ggstatsplot’
# Traceback:
#
# 1. library(ggstatsplot)

# %% [markdown]
# # ANOVA DE DOS VÍAS
#
# El siguiente es el código R para la realización de un ANOVA de dos vías con el conjunto de datos `Soils` utilizando R. En este caso, consideraré `Block`, `Contour`, y `Depth` como factores. Aquí tienes un ejemplo de cómo realizarlo:
#
# ```R
# # Carga de paquetes si aún no están instalados
# # install.packages(c("car", "carData"))
#
# # Carga de paquetes
# library(car)
# library(carData)
#
# # Carga de datos
# data(Soils)
#
# # ANOVA de dos vías
# modelo_anova <- aov(cbind(pH, N, Dens, P, Ca, Mg, K, Na, Conduc) ~ Block * Contour * Depth, data = Soils)
#
# # Resumen del ANOVA
# summary(modelo_anova)
# ```
#
# En este código:
#
# - `cbind(pH, N, Dens, P, Ca, Mg, K, Na, Conduc) ~ Block * Contour * Depth` especifica que estás interesado en analizar múltiples variables de respuesta (pH, N, Dens, P, Ca, Mg, K, Na, Conduc) en función de los factores `Block`, `Contour`, y `Depth`, y todas las interacciones entre ellos.
#
# - `aov()` se utiliza para ajustar el modelo ANOVA.
#
# - `summary()` se utiliza para obtener un resumen de los resultados del ANOVA.
#
# Este código realizará un ANOVA de dos vías en el conjunto de datos `Soils`. Asegúrate de ajustar las variables y factores según tus necesidades específicas. Si tienes alguna pregunta adicional o necesitas más ayuda, no dudes en preguntar.

# %% [markdown]
# # Grafica del ANOVA de dos vías
#
# La función `ggbetweenstats()` del paquete `ggstatsplot` está diseñada principalmente para comparar las medias entre niveles de una variable categórica, utilizando gráficos de violín y diagramas de puntos. Para un ANOVA de dos vías, donde hay interacciones entre múltiples factores, esta función puede no proporcionar una representación directa y fácil.
#
# Sin embargo, puedes utilizar la función `interaction_plot()` para visualizar las interacciones entre dos factores en un ANOVA de dos vías. Aquí tienes un ejemplo utilizando el conjunto de datos `Soils`:
#
# ```R
# # Carga de paquetes si aún no están instalados
# # install.packages(c("car", "carData", "ggplot2"))
#
# # Carga de paquetes
# library(car)
# library(carData)
# library(ggplot2)
#
# # Carga de datos
# data(Soils)
#
# # ANOVA de dos vías
# modelo_anova <- aov(cbind(pH, N, Dens, P, Ca, Mg, K, Na, Conduc) ~ Block * Contour * Depth, data = Soils)
#
# # Interaction plot para dos factores
# interaction_plot(x.factor = Soils$Contour,
#                  trace.factor = Soils$Depth,
#                  response = modelo_anova$residuals[, "pH"],
#                  type = "b",
#                  fixed = TRUE,
#                  legend = TRUE,
#                  col = c("red", "blue", "green", "purple"),
#                  xlab = "Contour",
#                  ylab = "Residuals",
#                  pch = c(1, 2, 3, 4))
# ```
#
# En este ejemplo, se ha seleccionado la variable de respuesta `pH` para ilustrar la interacción entre los factores `Contour` y `Depth`. Puedes ajustar la variable de respuesta según tus necesidades.
#
# Recuerda que este tipo de gráfico se centra en visualizar la interacción entre dos factores a la vez, y podrías necesitar generar gráficos adicionales para explorar otras interacciones.
#
# Si necesitas más ayuda o tienes alguna pregunta específica, no dudes en preguntar.
